-- %%
USE SCHEMA `playground-databricks`;

CREATE OR REPLACE TABLE `workspace`.`playground-databricks`.`cars` (
  `id` INT,
  `model` STRING,
  `brand` STRING,
  `year` INT
);

INSERT INTO `workspace`.`playground-databricks`.`cars`
VALUES (1, 'Mustang', 'Ford', 2020),
       (2, 'Civic', 'Honda', 2019),
       (3, 'Accord', 'Honda', 2020),
       (4, 'Camry', 'Toyota', 2019),
       (5, 'Corolla', 'Toyota', 2020),
       (6, 'Cybertruck', 'Tesla', 2023),
       (7, 'Model S', 'Tesla', 2023),
       (8, 'Model Y', 'Tesla', 2022),
       (9, 'Model X 75D', 'Tesla', 2017);

-- %%
CREATE TEMP VIEW temp_view_cars_brands
AS SELECT DISTINCT brand
FROM cars;

-- %%
SHOW TABLES
